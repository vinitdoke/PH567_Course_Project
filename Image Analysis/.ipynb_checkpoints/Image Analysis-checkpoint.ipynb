# %%
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
# %matplotlib inline

# %%
orig = cv.imread("orig.png")
orig = cv.cvtColor(orig, cv.COLOR_BGR2GRAY)
encr = cv.imread("encr.png")[:,:,0]
decr = cv.imread("decr.png")[:,:,0]

# %% [markdown]
# # A. Statistical Analysis
# ## 1. Histogram

# %%
def plotHist(img):
    plt.hist(img.ravel(),256,[0,256])
#     plt.savefig("encr_hist.png")
    return None

# %%
plotHist(encr)

# %%
plt.imshow(encr)

# %%
plotHist(orig)

# %%
plt.imshow(orig)

# %%
plotHist(decr)

# %%
plt.imshow(decr)

# %% [markdown]
# ## 2. Correlation Coefficient

# %%
def funcE(img):
    M,N = img.shape[0], img.shape[1]
    summ = 0
    for i in range(M):
        for j in range(N):
            summ += img[i,j]
    return summ/(M*N)

def funcD(img, E):
    M,N = img.shape[0], img.shape[1]
    summ = 0
    for i in range(M):
        for j in range(N):
            summ += (img[i,j]-E)**2
    return summ/(M*N)

def CovH(img, E):
    M,N = img.shape[0], img.shape[1]
    summ = 0
    for i in range(M):
        for j in range(N-1):
            summ += (img[i,j]-E)*(img[i,j+1]-E)
    return summ/(M*N)

def CovV(img, E):
    M,N = img.shape[0], img.shape[1]
    summ = 0
    for i in range(M-1):
        for j in range(N):
            summ += (img[i,j]-E)*(img[i+1,j]-E)
    return summ/(M*N)

def CovD(img, E):
    M,N = img.shape[0], img.shape[1]
    summ = 0
    for i in range(M-1):
        for j in range(N-1):
            summ += (img[i,j]-E)*(img[i+1, j+1] - E)
    return summ/(M*N)
    
    
def rH(img):
    E = funcE(img)
    return CovH(img, E)/funcD(img,E)
def rV(img):
    E = funcE(img)
    return CovV(img, E)/funcD(img,E)
def rD(img):
    E = funcE(img)
    return CovD(img, E)/funcD(img,E)

# %%
rH(orig), rH(encr), rH(decr)
# Out:
# (0.9749791179244875, 0.030391415988294014, 0.9749791179244875)

# %%
rV(orig), rV(encr), rV(decr)
# Out:
# (0.9775069679355488, 0.0026855495035867684, 0.9775069679355488)

# %%
rD(orig), rD(encr), rD(decr)
# Out:
# (0.9597030965537723, -0.00032245389241540687, 0.9597030965537723)

# %% [markdown]
# ## 3. Scatter Plots

# %%
def plotScatter(img):
    M,N = img.shape[0], img.shape[1]
    xval = []
    yval = []
    for i in range(1,M):
        for j in range(N):
            xval.append(img[i,j])
            yval.append(img[i-1,j])
    plt.scatter(xval, yval, s =1)
#     plt.savefig("encryp_covplot.png")
    return

# %%
plotScatter(orig)

# %%
plotScatter(encr)

# %%
plotScatter(decr)

# %% [markdown]
# # B. Entropy Calculation

# %%
def CalcEntropy(img):
    M,N = img.shape[0], img.shape[1]
    frequencies = np.array([0 for i in range(256)])
    for i in range(M):
        for j in range(N):
            intensityvalue = img[i,j]
            frequencies[intensityvalue] += 1
    probability = frequencies/(M*N)
    summ = 0
    for i in range(256):
        num = probability[i] 
        if  num == 0:
            continue
        else:
            summ += (-1*num*np.log2(num))
    return summ

# %%
CalcEntropy(orig), CalcEntropy(encr), CalcEntropy(decr)
# Out:
# (7.087035652073013, 7.99934170068765, 7.087035652073013)
